# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas_profiling
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\Mannu sharma\Anaconda3\lib\site-packages\pandas_profiling\plot.py:15: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "C:\Users\Mannu sharma\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Users\Mannu sharma\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\Mannu sharma\Anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\Mannu sharma\Anaconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
# ...

# %%
train=pd.read_csv('C:/Users/Mannu sharma/Desktop/BA/ML/black friday/train.csv')

# %%
pandas_profiling.ProfileReport(train)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
train.corr()
# Out:
#                      User_ID  Occupation  Marital_Status  Product_Category_1  \
# User_ID             1.000000   -0.023971        0.020443            0.003825
# Occupation         -0.023971    1.000000        0.024280           -0.007618
# Marital_Status      0.020443    0.024280        1.000000            0.019888
# Product_Category_1  0.003825   -0.007618        0.019888            1.000000
# Product_Category_2  0.001529   -0.000384        0.015138            0.540583
# Product_Category_3  0.003419    0.013263        0.019473            0.229678
# Purchase            0.004716    0.020833       -0.000463           -0.343703
#
#                     Product_Category_2  Product_Category_3  Purchase
# User_ID                       0.001529            0.003419  0.004716
# Occupation                   -0.000384            0.013263  0.020833
# Marital_Status                0.015138            0.019473 -0.000463
# Product_Category_1            0.540583            0.229678 -0.343703
# ...

# %%
train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# ...

# %%
train.shape
# Out:
# (550068, 12)

# %%
train.dtypes
# Out:
# User_ID                         int64
# Product_ID                     object
# Gender                         object
# Age                            object
# Occupation                      int64
# City_Category                  object
# Stay_In_Current_City_Years     object
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object

# %%
train.isna().sum()
# Out:
# User_ID                            0
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# City_Category                      0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            173638
# Product_Category_3            383247
# Purchase                           0
# dtype: int64

# %%
train.boxplot(['Product_Category_2'])

# %%
train['Product_Category_2'].describe()
# Out:
# count    376430.000000
# mean          9.842329
# std           5.086590
# min           2.000000
# 25%           5.000000
# 50%           9.000000
# 75%          15.000000
# max          18.000000
# Name: Product_Category_2, dtype: float64

# %%
train.boxplot(['Product_Category_3'])

# %%
train['Product_Category_3'].describe()
# Out:
# count    166821.000000
# mean         12.668243
# std           4.125338
# min           3.000000
# 25%           9.000000
# 50%          14.000000
# 75%          16.000000
# max          18.000000
# Name: Product_Category_3, dtype: float64

# %%
train.corr()
# Out:
#                      User_ID  Occupation  Marital_Status  Product_Category_1  \
# User_ID             1.000000   -0.023971        0.020443            0.003825
# Occupation         -0.023971    1.000000        0.024280           -0.007618
# Marital_Status      0.020443    0.024280        1.000000            0.019888
# Product_Category_1  0.003825   -0.007618        0.019888            1.000000
# Product_Category_2  0.001529   -0.000384        0.015138            0.540583
# Product_Category_3  0.003419    0.013263        0.019473            0.229678
# Purchase            0.004716    0.020833       -0.000463           -0.343703
#
#                     Product_Category_2  Product_Category_3  Purchase
# User_ID                       0.001529            0.003419  0.004716
# Occupation                   -0.000384            0.013263  0.020833
# Marital_Status                0.015138            0.019473 -0.000463
# Product_Category_1            0.540583            0.229678 -0.343703
# ...

# %%
train['Product_Category_2'].unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
train['Product_Category_3'].value_counts()
# Out:
# 16.0    32636
# 15.0    28013
# 14.0    18428
# 17.0    16702
# 5.0     16658
# 8.0     12562
# 9.0     11579
# 12.0     9246
# 13.0     5459
# 6.0      4890
# 18.0     4629
# 4.0      1875
# 11.0     1805
# 10.0     1726
# 3.0       613
# Name: Product_Category_3, dtype: int64

# %%
train['Product_Category_3'].isna().sum()
# Out:
# 383247

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
ohe=OneHotEncoder(sparse=False)
le=LabelEncoder()

# %%
bb=train['Product_Category_3'].unique()
bb
# Out:
# array([nan, 14., 17.,  5.,  4., 16., 15.,  8.,  9., 13.,  6., 12.,  3.,
#        18., 11., 10.])

# %%
product_encoded=le.fit_transform(bb)
product_encoded
# Out:
# array([15, 10, 13,  2,  1, 12, 11,  4,  5,  9,  3,  8,  0, 14,  7,  6],
#       dtype=int64)

# %%
encoded1=le.fit_transform(train['Product_Category_2'].unique())

# %%
encoded1
# Out:
# array([17,  4, 12,  0,  6, 13, 14,  9,  3,  1,  2, 10,  7,  8, 15, 11,  5,
#        16], dtype=int64)

# %%
a2=aaa['Gender']
a3=aaa['Age']
a4=aaa['City_Category']
a5=aaa['Stay_In_Current_City_Years']

# %%
train['User_ID']=le.fit_transform(train['User_ID'])
train['Product_ID']=le.fit_transform(train['Product_ID'])

# %%
train['Gender']=le.fit_transform(train['Gender'])
train['Age']=le.fit_transform(train['Age'])
train['City_Category']=le.fit_transform(train['City_Category'])
train['Stay_In_Current_City_Years']=le.fit_transform(train['Stay_In_Current_City_Years'])
train
# Out:
#         User_ID Product_ID  Gender  Age  Occupation  City_Category  \
# 0       1000001  P00069042       0    0          10              0
# 1       1000001  P00248942       0    0          10              0
# 2       1000001  P00087842       0    0          10              0
# 3       1000001  P00085442       0    0          10              0
# 4       1000002  P00285442       1    6          16              2
# 5       1000003  P00193542       1    2          15              0
# 6       1000004  P00184942       1    4           7              1
# 7       1000004  P00346142       1    4           7              1
# 8       1000004   P0097242       1    4           7              1
# 9       1000005  P00274942       1    2          20              0
# 10      1000005  P00251242       1    2          20              0
# 11      1000005  P00014542       1    2          20              0
# 12      1000005  P00031342       1    2          20              0
# ...

# %%
aaa=pd.get_dummies(train,columns=['Product_Category_2','Product_Category_3'])
aaa.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase  \
# 0                          2               0                   3      8370
# 1                          2               0                   1     15200
# 2                          2               0                  12      1422
# 3                          2               0                  12      1057
# 4                         4+               0                   8      7969
#
#             ...             Product_Category_3_9.0  Product_Category_3_10.0  \
# ...

# %%
aaa.isna().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category_1            0
# Purchase                      0
# Product_Category_2_2.0        0
# Product_Category_2_3.0        0
# Product_Category_2_4.0        0
# Product_Category_2_5.0        0
# Product_Category_2_6.0        0
# Product_Category_2_7.0        0
# Product_Category_2_8.0        0
# Product_Category_2_9.0        0
# Product_Category_2_10.0       0
# Product_Category_2_11.0       0
# Product_Category_2_12.0       0
# Product_Category_2_13.0       0
# Product_Category_2_14.0       0
# Product_Category_2_15.0       0
# Product_Category_2_16.0       0
# Product_Category_2_17.0       0
# Product_Category_2_18.0       0
# Product_Category_3_3.0        0
# Product_Category_3_4.0        0
# ...

# %%
aaa.shape
# Out:
# (550068, 42)

# %%
pandas_profiling.ProfileReport(aaa)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %%
a1=train['Purchase']
a1
# Out:
# 0          8370
# 1         15200
# 2          1422
# 3          1057
# 4          7969
# 5         15227
# 6         19215
# 7         15854
# 8         15686
# 9          7871
# 10         5254
# 11         3957
# 12         6073
# 13        15665
# 14         5378
# 15         2079
# 16        13055
# 17         8851
# 18        11788
# 19        19614
# 20         8584
# 21         9872
# 22         9743
# 23         5982
# 24        11927
# 25        16662
# 26         5887
# 27         6973
# 28         5391
# 29        16352
#           ...
# 550038      596
# 550039      595
# 550040       26
# 550041      488
# 550042      243
# 550043       48
# 550044       62
# 550045      252
# 550046      236
# 550047      244
# 550048      591
# 550049      473
# 550050      368
# 550051      489
# 550052      239
# 550053      371
# 550054       60
# 550055      238
# 550056      254
# 550057       61
# 550058      121
# 550059       48
# 550060      494
# 550061      599
# ...

# %%
train_f=pd.concat([aaa,a1],axis=1)
train_f
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# 5       1000003  P00193542      M  26-35          15             A
# 6       1000004  P00184942      M  46-50           7             B
# 7       1000004  P00346142      M  46-50           7             B
# 8       1000004   P0097242      M  46-50           7             B
# 9       1000005  P00274942      M  26-35          20             A
# 10      1000005  P00251242      M  26-35          20             A
# 11      1000005  P00014542      M  26-35          20             A
# 12      1000005  P00031342      M  26-35          20             A
# ...

# %%
corr=train_f.corr()
corr
# Out:
#                               User_ID  Occupation  Marital_Status  \
# User_ID                  1.000000e+00   -0.023971        0.020443
# Occupation              -2.397072e-02    1.000000        0.024280
# Marital_Status           2.044264e-02    0.024280        1.000000
# Product_Category_1       3.824614e-03   -0.007618        0.019888
# Purchase                 4.715662e-03    0.020833       -0.000463
# Product_Category_2_2.0  -8.916758e-04    0.010934       -0.010580
# Product_Category_2_3.0  -3.899447e-03   -0.000120       -0.005039
# Product_Category_2_4.0  -3.783948e-03   -0.006331       -0.011455
# Product_Category_2_5.0   2.255754e-03    0.001421       -0.007203
# Product_Category_2_6.0   1.925347e-03    0.002811       -0.001808
# Product_Category_2_7.0  -3.573668e-03   -0.002092        0.000061
# Product_Category_2_8.0   4.092051e-03   -0.001214        0.005533
# Product_Category_2_9.0   4.388770e-03   -0.000602       -0.002270
# ...

# %%
a11=corr[(corr>0.4) | (corr<-0.4)]       
a1
# Out:
# 0          8370
# 1         15200
# 2          1422
# 3          1057
# 4          7969
# 5         15227
# 6         19215
# 7         15854
# 8         15686
# 9          7871
# 10         5254
# 11         3957
# 12         6073
# 13        15665
# 14         5378
# 15         2079
# 16        13055
# 17         8851
# 18        11788
# 19        19614
# 20         8584
# 21         9872
# 22         9743
# 23         5982
# 24        11927
# 25        16662
# 26         5887
# 27         6973
# 28         5391
# 29        16352
#           ...
# 550038      596
# 550039      595
# 550040       26
# 550041      488
# 550042      243
# 550043       48
# 550044       62
# 550045      252
# 550046      236
# 550047      244
# 550048      591
# 550049      473
# 550050      368
# 550051      489
# 550052      239
# 550053      371
# 550054       60
# 550055      238
# 550056      254
# 550057       61
# 550058      121
# 550059       48
# 550060      494
# 550061      599
# ...

# %%
aaa

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split

# %%
aaa=aaa.drop(['User_ID','Product_ID',],axis=1)

# %%
aaa=aaa.drop(['Purchase'],axis=1)

# %%
aaa.columns
# Out:
# Index(['Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2_2.0', 'Product_Category_2_3.0',
#        'Product_Category_2_4.0', 'Product_Category_2_5.0',
#        'Product_Category_2_6.0', 'Product_Category_2_7.0',
#        'Product_Category_2_8.0', 'Product_Category_2_9.0',
#        'Product_Category_2_10.0', 'Product_Category_2_11.0',
#        'Product_Category_2_12.0', 'Product_Category_2_13.0',
#        'Product_Category_2_14.0', 'Product_Category_2_15.0',
#        'Product_Category_2_16.0', 'Product_Category_2_17.0',
#        'Product_Category_2_18.0', 'Product_Category_3_3.0',
#        'Product_Category_3_4.0', 'Product_Category_3_5.0',
#        'Product_Category_3_6.0', 'Product_Category_3_8.0',
#        'Product_Category_3_9.0', 'Product_Category_3_10.0',
#        'Product_Category_3_11.0', 'Product_Category_3_12.0',
# ...

# %%
dt=DecisionTreeRegressor()

# %%
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
a3=train['Purchase']

# %%
a3.head()
# Out:
# 0     8370
# 1    15200
# 2     1422
# 3     1057
# 4     7969
# Name: Purchase, dtype: int64

# %%
train['Product_Category_2']=train['Product_Category_2'].replace(to_replace=np.nan,value=0)

# %%
train['Product_Category_3']=train['Product_Category_3'].replace(to_replace=np.nan,value=0)

# %%
train.Product_Category_2 = pd.to_numeric(train.Product_Category_2)
train.Product_Category_3 = pd.to_numeric(train.Product_Category_3)

# %%
t3=train.drop('Purchase',axis=1)

# %%
t3
# Out:
#         User_ID  Product_ID  Gender  Age  Occupation  City_Category  \
# 0             0         672       0    0          10              0
# 1             0        2376       0    0          10              0
# 2             0         852       0    0          10              0
# 3             0         828       0    0          10              0
# 4             1        2734       1    6          16              2
# 5             2        1831       1    2          15              0
# 6             3        1745       1    4           7              1
# 7             3        3320       1    4           7              1
# 8             3        3604       1    4           7              1
# 9             4        2631       1    2          20              0
# 10            4        2398       1    2          20              0
# 11            4         140       1    2          20              0
# 12            4         307       1    2          20              0
# ...

# %%
t4=pd.get_dummies(t3,columns=['Product_Category_2','Product_Category_3'])

# %%
from sklearn.preprocessing import StandardScaler

# %%
SS = StandardScaler()
t5 = pd.DataFrame(SS.fit_transform(t4))

# %%
t5.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -1.746513 -1.844248  0.294864 -1.371516  0.109801 -0.833018 -0.610809
# 1 -1.746513 -1.844248  0.294864 -1.371516  0.109801 -0.833018 -1.118912
# 2 -1.746513 -1.844248  0.294864 -1.371516  0.109801 -0.833018  1.675656
# 3 -1.746513 -1.844248  0.294864 -1.371516  0.109801 -0.833018  1.675656
# 4  0.572570  2.588277  1.214734  1.259336  1.660861 -0.833018  0.659449
#
#          7         8         9     ...           29        30        31  \
# 0 -0.313475 -0.072599 -0.221281    ...    -0.146638 -0.056104 -0.057378
# 1 -0.313475 -0.072599 -0.221281    ...    -0.146638 -0.056104 -0.057378
# 2 -0.313475 -0.072599 -0.221281    ...    -0.146638 -0.056104 -0.057378
# 3 -0.313475 -0.072599 -0.221281    ...    -0.146638 -0.056104 -0.057378
# 4 -0.313475 -0.072599 -0.221281    ...    -0.146638 -0.056104 -0.057378
#
#          32        33        34        35        36        37        38
# ...

# %%
t4=t4.drop(['User_ID','Product_ID'],axis=1)
t4.head()
# Out:
#    Gender  Age  Occupation  City_Category  Stay_In_Current_City_Years  \
# 0       0    0          10              0                           2
# 1       0    0          10              0                           2
# 2       0    0          10              0                           2
# 3       0    0          10              0                           2
# 4       1    6          16              2                           4
#
#    Marital_Status  Product_Category_1  Product_Category_2_2.0  \
# 0               0                   3                       0
# 1               0                   1                       0
# 2               0                  12                       0
# 3               0                  12                       0
# 4               0                   8                       0
#
#    Product_Category_2_3.0  Product_Category_2_4.0           ...             \
# 0                       0                       0           ...
# ...

# %%
X_train, X_test, y_train, y_test= train_test_split(t5,a3,test_size=0.4, random_state=0)

# %%
from sklearn.metrics import r2_score

# %%
y_pred=dt.predict(X_test)

# %%
y_pred1=dt.predict(X_test)

# %%
y_pred2=dt.predict(X_test)

# %%
df=pd.DataFrame({'Actual': y_test,'Predicted': y_pred2})
df

# %%
from sklearn.metrics import cohen_kappa_score
from sklearn import metrics

# %%
print("Mean Absolute error", metrics.mean_absolute_error(y_test, y_pred))
print("Mean Squared Error", metrics.mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error", np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute error 2386.9808283569027
# Mean Squared Error 11474385.34142387
# Root Mean Squared Error 3387.386210845151

# %%
print("Mean Absolute error", metrics.mean_absolute_error(y_test, y_pred1))
print("Mean Squared Error", metrics.mean_squared_error(y_test, y_pred1))
print("Root Mean Squared Error", np.sqrt(metrics.mean_squared_error(y_test, y_pred1)))
# Out:
# Mean Absolute error 2394.4189240551714
# Mean Squared Error 11536523.842801029
# Root Mean Squared Error 3396.545869379807

# %%
print("Mean Absolute error", metrics.mean_absolute_error(y_test, y_pred2))
print("Mean Squared Error", metrics.mean_squared_error(y_test, y_pred2))
print("Root Mean Squared Error", np.sqrt(metrics.mean_squared_error(y_test, y_pred2)))
# Out:
# Mean Absolute error 2387.0713752302295
# Mean Squared Error 11482702.179278389
# Root Mean Squared Error 3388.6136072556856

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test, y_pred)
# Out:
# 0.5460470209054215

# %%
r2_score(y_test, y_pred1)
# Out:
# 0.5435886793928003

# %%
r2_score(y_test, y_pred2)
# Out:
# 0.5467979334134951

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf=RandomForestRegressor()

# %%
jj=rf.fit(X_train,y_train)

# %%
jj
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
y_predict2=jj.predict(X_test)

# %%
y_predict3=jj.predict(X_test)

# %%
y_predict4=jj.predict(X_test)

# %%
df1=pd.DataFrame({'Actual': y_test,'Predicted': y_predict4})
df1
# Out:
#         Actual     Predicted
# 41001    15228  15314.816667
# 16151     1088   1234.508333
# 507262   16426  14786.550000
# 368698   12042  14420.430000
# 353782    8699   5977.894677
# 358687    9758   7480.706316
# 301389    4050   6862.466667
# 278980    7980   7508.900000
# 47994     5399   6183.186615
# 416377   12895  11007.108333
# 266930    6942   5187.641800
# 226794   20901  13797.190000
# 525409    8069   6398.440000
# 490544    3042   3117.533333
# 139180    6170   6846.898333
# 351374    5389   5866.881250
# 194821    7001   5843.062751
# 346419   15655  14255.033333
# 360095   12083  13602.398333
# 249040    6950   5999.862836
# 347094    9926   5854.256781
# 1398      6409  11023.800000
# 148746    7080   6631.849444
# 84873    10045   7716.492582
# 147779    1892   5064.966667
# 103865    5389   4970.332381
# 470708   11584  11464.050000
# 527931   20866  16943.241667
# 435287   20479  15911.029167
# 269847   16518  15050.732267
# ...        ...           ...
# ...

# %%
print('Mean Absolute Error', metrics.mean_absolute_error(y_test, y_predict1))
print('Mean Squared Error', metrics.mean_squared_error(y_test, y_predict1))
print('Root Mean Squared Error', np.sqrt(metrics.mean_squared_error(y_test, y_predict1)))
# Out:
# Mean Absolute Error 2255.701160391328
# Mean Squared Error 9634820.245186849
# Root Mean Squared Error 3104.0006838251256

# %%
print('Mean Absolute Error', metrics.mean_absolute_error(y_test, y_predict2))
print('Mean Squared Error', metrics.mean_squared_error(y_test, y_predict2))
print('Root Mean Squared Error', np.sqrt(metrics.mean_squared_error(y_test, y_predict2)))
# Out:
# Mean Absolute Error 2261.224370979186
# Mean Squared Error 9675705.741543818
# Root Mean Squared Error 3110.5796471950075

# %%
print('Mean Absolute Error', metrics.mean_absolute_error(y_test, y_predict3))
print('Mean Squared Error', metrics.mean_squared_error(y_test, y_predict3))
print('Root Mean Squared Error', np.sqrt(metrics.mean_squared_error(y_test, y_predict3)))
# Out:
# Mean Absolute Error 2254.6751574517007
# Mean Squared Error 9636078.560546555
# Root Mean Squared Error 3104.203369714451

# %%
print('Mean Absolute Error', metrics.mean_absolute_error(y_test, y_predict4))
print('Mean Squared Error', metrics.mean_squared_error(y_test, y_predict4))
print('Root Mean Squared Error', np.sqrt(metrics.mean_squared_error(y_test, y_predict4)))
# Out:
# Mean Absolute Error 2254.307875812434
# Mean Squared Error 9628628.305765454
# Root Mean Squared Error 3103.0031108211047

# %%
r2_score(y_test, y_predict1)
# Out:
# 0.6188244317058482

# %%
r2_score(y_test, y_predict2)
# Out:
# 0.6172069077757425

# %%
print("Accuracy Score of Random Forests on test set",jj.score(X_train,y_train)*100)
# Out:
# Accuracy Score of Random Forests on test set 79.39358418327623

# %%
print("Accuracy Score of Random Forests on test set",jj.score(X_test,y_test)*100)
# Out:
# Accuracy Score of Random Forests on test set 61.86855554700583

# %%
print("Accuracy Score of Random Forests on test set",jj.score(X_train,y_train)*100)
# Out:
# Accuracy Score of Random Forests on test set 79.41868657253596

# %%
print("Accuracy Score of Random Forests on test set",jj.score(X_test,y_test)*100)
# Out:
# Accuracy Score of Random Forests on test set 61.87746498666314

# %%
print("Accuracy Score of Random Forests on test set",jj.score(X_test,y_test)*100)
# Out:
# Accuracy Score of Random Forests on test set 61.90693990189615

# %%
train.dtypes
# Out:
# User_ID                         int64
# Product_ID                      int64
# Gender                          int64
# Age                             int64
# Occupation                      int64
# City_Category                   int64
# Stay_In_Current_City_Years      int64
# Marital_Status                  int64
# Product_Category_1              int64
# Product_Category_2            float64
# Product_Category_3            float64
# Purchase                        int64
# dtype: object
